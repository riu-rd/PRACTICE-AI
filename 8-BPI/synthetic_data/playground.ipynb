# %%
import pandas as pd

df = pd.read_csv("synthetic_data.csv")
df.head(200)
# Out:
#     case_id       case_text_value_type  \
# 0    C00001             Single message
# 1    C00002  User-chatbot conversation
# 2    C00003          Multiple messages
# 3    C00004             Single message
# 4    C00005             Single message
# ..      ...                        ...
# 195  C00196             Single message
# 196  C00197  User-chatbot conversation
# 197  C00198          Multiple messages
# 198  C00199             Single message
# 199  C00200             Single message
#
#                                              case_text case_source  \
# 0    Hello, BPI! Hindi ko po makita yung bagong cre...       Email
# 1    ['User: I want to apply for a personal loan.',...       Phone
# 2    ['Bakit po ang tagal bago mag-reflect yung tra...    Facebook
# 3    Good day! I would like to inquire about the in...      Branch
# 4    Di ko po ma-access yung BPI mobile app ko. Lag...       Phone
# ..                                                 ...         ...
# ...

# %%
def display_case_texts(n):
    """
    Display the case_text of the first n rows in the dataframe df.
    """
    for i, text in enumerate(df['case_text'].head(n), 1):
        print(f"Case {i}:\n{text}\n{'-'*40}")

# Example usage:
# display_case_texts(5)

# %%
display_case_texts(100)
# Out:
# Case 1:
# Hello, BPI! Hindi ko po makita yung bagong credit card ko sa BPI online banking. Paano po kaya?
# ----------------------------------------
# Case 2:
# ['User: I want to apply for a personal loan.', 'Chatbot: Great! Do you have an existing BPI account?', 'User: Yes, I do.', 'Chatbot: Please provide your account number.', 'User: 1234567890', 'Chatbot: Thank you. Please wait while I check your eligibility.']
# ----------------------------------------
# Case 3:
# ['Bakit po ang tagal bago mag-reflect yung transfer ko sa BPI savings account ko?', 'I transferred it yesterday pa po.', 'Pwede po ba paki-check? Urgent po kasi.']
# ----------------------------------------
# Case 4:
# Good day! I would like to inquire about the interest rates for time deposits. Thanks!
# ----------------------------------------
# Case 5:
# Di ko po ma-access yung BPI mobile app ko. Laging error. Paano po ba to?
# ----------------------------------------
# Case 6:
# ...
